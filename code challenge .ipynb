# %%
import requests

# %%
download_url = "https://raw.githubusercontent.com/onaio/ona-tech/master/data/water_points.json"

# %%
target_json_path = "water_points.json"

# %%
response = requests.get(download_url)
response.raise_for_status()  # Check that the request was successful

# %%
with open(target_json_path, "wb") as f:
    f.write(response.content)
print("Download ready.")
# Out:
# Download ready.

# %%
import pandas as pd

# %%
water_point = pd.read_json("water_points.json")

# %%
type(water_point)
# Out:
# pandas.core.frame.DataFrame

# %%
len(water_point)
# Out:
# 712

# %%
water_point.shape
# Out:
# (712, 48)

# %%
pd.set_option("display.max.columns", None)

# %%
pd.set_option("display.precision", 2)

# %%
pd.set_option("max_rows", None)
water_point
# Out:
#     water_pay                 respondent research_asst_name water_used_season  \
# 0          no                  community    Haruna Mohammed        year_round
# 1          no                  community     Haruna Mohmmed        year_round
# 2          no                  community    Haruna Mohammed        year_round
# 3          no                  community    Haruna Mohammed        year_round
# 4          no                  community    Haruna Mohammed        year_round
# 5          no                  community    Haruna Mohammed        year_round
# 6          no                  community    Haruna Mohammed        year_round
# 7          no                  community    Haruna Mohammed        year_round
# 8       na_dn                  community    Haruna Mohammed        year_round
# 9          no                  community    Haruna Mohammed        year_round
# 10         no                  community    Haruna Mohammed        year_round
# ...

# %%
water_point["communities_villages"].value_counts() #the number of water points per community
# Out:
# Kpatarigu           51
# Jagsa               38
# Nayoku              35
# Guuta               32
# Nabulugu            31
# Zundem              30
# Zua                 28
# Badomsa             27
# Bechinsa            26
# Kaasa               25
# Tantala             22
# Zuedema             18
# Loagri_1_           18
# Kubore              18
# Dorinsa             17
# Selinvoya           13
# Zangu-Vuga          13
# Arigu               12
# Guuta-Nasa          11
# Kulbugu             11
# Zanwara             10
# Banyangsa           10
# Chansa               9
# Longsa               9
# Kurugu               9
# Kanwaasa             9
# Kanbangsa            8
# Namgurima            8
# Jiriwiensa           8
# Mwalorinsa           8
# Jaata                8
# Luisa                8
# Nyankpiensa          8
# Bandem               7
# Jiningsa             7
# Soo                  7
# Tankangsa            6
# Kom                  6
# Zogsa                6
# Zukpeni              6
# ...

# %%
water_point["water_functioning"].value_counts() #the number of water points that are functioning
# Out:
# yes      623
# no        87
# na_dn      2
# Name: water_functioning, dtype: int64
